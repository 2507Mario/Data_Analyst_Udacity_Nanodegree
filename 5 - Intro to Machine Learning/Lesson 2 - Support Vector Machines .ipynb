# %%
from sklearn import svm
# Features
X = [[0, 0], [1, 1]]
y = [0, 1]

# create classifier
clf = svm.SVC()

#fit classifier
clf.fit(X, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# make a prediction
clf.predict([[2., 2.]])
# Out:
# array([1])

# %%
#!/usr/bin/python

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""
    
import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()

#########################################################
### your code goes here ###

print("Original size of features: ", len(features_train))
from sklearn.svm import SVC
print(1)
clf = SVC(kernel="linear")
print(2)
t0 = time()
clf.fit(features_train, labels_train)
print(3)
pred = clf.predict(features_test)
print(4)


from sklearn.metrics import accuracy_score
acc = accuracy_score(labels_test, pred)
print("accuracy is ", acc)

#########################################################
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# ('Original size of features: ', 15820)
# 1
# 2
# 3
# 4
# ('accuracy is ', 0.98407281001137659)

# %%
#!/usr/bin/python

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""



# Now, we addd time:




import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()

#########################################################
### your code goes here ###

print("original size of features are ", len(features_train))
from sklearn.svm import SVC


clf = SVC(kernel="linear")


t0 = time()
clf.fit(features_train, labels_train)
print "training time:", round(time()-t0, 3), "s"

t0 = time()
pred = clf.predict(features_test)
print "predict time:", round(time()-t0, 3), "s"



from sklearn.metrics import accuracy_score
acc = accuracy_score(labels_test, pred)
print("accuracy is ", acc)

#########################################################
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# ('original size of features are ', 15820)
# training time: 129.12 s
# predict time: 13.411 s
# ('accuracy is ', 0.98407281001137659)

# %%
#!/usr/bin/python

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""



# Now, A Smaller Training Set:




import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()

#########################################################
### your code goes here ###

print("original size of features are ", len(features_train))
from sklearn.svm import SVC


clf = SVC(kernel="linear")


t0 = time()
features_train = features_train[:len(features_train)/100] 
labels_train = labels_train[:len(labels_train)/100] 
clf.fit(features_train, labels_train)
print "training time:", round(time()-t0, 3), "s"

t0 = time()
pred = clf.predict(features_test)
print "predict time:", round(time()-t0, 3), "s"



from sklearn.metrics import accuracy_score
acc = accuracy_score(labels_test, pred)
print("accuracy is: ", acc)

#########################################################
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# ('original size of features are ', 15820)
# training time: 0.074 s
# predict time: 0.786 s
# ('accuracy is: ', 0.88452787258248011)

# %%
#!/usr/bin/python

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""



# Now, A Smaller Training Set + RBF Kernel:




import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()

#########################################################
### your code goes here ###

print("original size of features are ", len(features_train))
from sklearn.svm import SVC


clf = SVC(kernel="rbf")


t0 = time()
features_train = features_train[:len(features_train)/100] 
labels_train = labels_train[:len(labels_train)/100] 
clf.fit(features_train, labels_train)
print "training time:", round(time()-t0, 3), "s"

t0 = time()
pred = clf.predict(features_test)
print "predict time:", round(time()-t0, 3), "s"



from sklearn.metrics import accuracy_score
acc = accuracy_score(labels_test, pred)
print("accuracy is: ", acc)

#########################################################
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# ('original size of features are ', 15820)
# training time: 0.084 s
# predict time: 0.884 s
# ('accuracy is: ', 0.61604095563139927)

# %%
#!/usr/bin/python

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""



# Now, A Smaller Training Set + RBF Kernel + Changing C value 10.0




import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()

#########################################################
### your code goes here ###

print("original size of features are ", len(features_train))
from sklearn.svm import SVC

# C = 10.0
clf = SVC(kernel="rbf", C=10.0)

t0 = time()
features_train = features_train[:len(features_train)/100] 
labels_train = labels_train[:len(labels_train)/100] 
clf.fit(features_train, labels_train)
print "training time:", round(time()-t0, 3), "s"

t0 = time()
pred = clf.predict(features_test)
print "predict time:", round(time()-t0, 3), "s"

from sklearn.metrics import accuracy_score
acc = accuracy_score(labels_test, pred)
print("accuracy with 10.0 is ", acc)

#########################################################
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# ('original size of features are ', 15820)
# training time: 0.083 s
# predict time: 0.874 s
# ('accuracy with 10.0 is ', 0.61604095563139927)

# %%
#!/usr/bin/python

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""



# Now, A Smaller Training Set + RBF Kernel + Changing C value 100.0




import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()

#########################################################
### your code goes here ###

print("original size of features are ", len(features_train))
from sklearn.svm import SVC

# C = 100.0

clf = SVC(kernel="rbf", C=100.0)

t0 = time()
features_train = features_train[:len(features_train)/100] 
labels_train = labels_train[:len(labels_train)/100] 
clf.fit(features_train, labels_train)
print "training time:", round(time()-t0, 3), "s"

t0 = time()
pred = clf.predict(features_test)
print "predict time:", round(time()-t0, 3), "s"

from sklearn.metrics import accuracy_score
acc = accuracy_score(labels_test, pred)
print("accuracy with 100.0 is ", acc)

#########################################################
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# ('original size of features are ', 15820)
# training time: 0.091 s
# predict time: 0.905 s
# ('accuracy with 100.0 is ', 0.61604095563139927)

# %%
#!/usr/bin/python

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""



# Now, A Smaller Training Set + RBF Kernel + Changing C value 1000.0




import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()

#########################################################
### your code goes here ###

print("original size of features are ", len(features_train))
from sklearn.svm import SVC

# C = 1000.0

clf = SVC(kernel="rbf", C=1000.0)

t0 = time()
features_train = features_train[:len(features_train)/100] 
labels_train = labels_train[:len(labels_train)/100] 
clf.fit(features_train, labels_train)
print "training time:", round(time()-t0, 3), "s"

t0 = time()
pred = clf.predict(features_test)
print "predict time:", round(time()-t0, 3), "s"

from sklearn.metrics import accuracy_score
acc = accuracy_score(labels_test, pred)
print("accuracy with 1000.0 is ", acc)

#########################################################
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# ('original size of features are ', 15820)
# training time: 0.08 s
# predict time: 0.85 s
# ('accuracy with 1000.0 is ', 0.82138794084186573)

# %%
#!/usr/bin/python

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""



# Now, A Smaller Training Set + RBF Kernel + Changing C value 10000.0




import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()

#########################################################
### your code goes here ###

print("original size of features are ", len(features_train))
from sklearn.svm import SVC

# C = 10000.0

clf = SVC(kernel="rbf", C=10000.0)

t0 = time()
features_train = features_train[:len(features_train)/100] 
labels_train = labels_train[:len(labels_train)/100] 
clf.fit(features_train, labels_train)
print "training time:", round(time()-t0, 3), "s"

t0 = time()
pred = clf.predict(features_test)
print "predict time:", round(time()-t0, 3), "s"

from sklearn.metrics import accuracy_score
acc = accuracy_score(labels_test, pred)
print("accuracy with 10000.0 is ", acc)

#########################################################
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# ('original size of features are ', 15820)
# training time: 0.081 s
# predict time: 0.72 s
# ('accuracy with 10000.0 is ', 0.89249146757679176)

# %%
#!/usr/bin/python

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""



# Now, Full Training Set + RBF Kernel + Changing C value 10000.0




import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()

#########################################################
### your code goes here ###

print("original size of features are ", len(features_train))
from sklearn.svm import SVC

# C = 10000.0

clf = SVC(kernel="rbf", C=10000.0)

t0 = time()
#features_train = features_train[:len(features_train)/100] 
#labels_train = labels_train[:len(labels_train)/100] 
clf.fit(features_train, labels_train)
print "training time:", round(time()-t0, 3), "s"

t0 = time()
pred = clf.predict(features_test)
print "predict time:", round(time()-t0, 3), "s"

from sklearn.metrics import accuracy_score
acc = accuracy_score(labels_test, pred)
print("accuracy with 10000.0 and full training set is ", acc)

#########################################################
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# ('original size of features are ', 15820)
# training time: 84.615 s
# predict time: 8.457 s
# ('accuracy with 10000.0 and full training set is ', 0.99089874857792948)

# %%
#!/usr/bin/python

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""



# Now, 1% Training Set + RBF Kernel + C value 10000.0
# What class does your SVM (0 or 1, corresponding to Sara and Chris
# (respectively) predict for element 10 of the test set? The 26th? The 50th? 




import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()

#########################################################
### your code goes here ###

print("original size of features are ", len(features_train))
from sklearn.svm import SVC

# C = 10000.0

clf = SVC(kernel="rbf", C=10000.0)

t0 = time()
# 1% training set
features_train = features_train[:len(features_train)/100] 
labels_train = labels_train[:len(labels_train)/100]
clf.fit(features_train, labels_train)
print "training time:", round(time()-t0, 3), "s"

t0 = time()
pred = clf.predict(features_test[50])
print "predict time:", round(time()-t0, 3), "s"

print pred

#########################################################
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# ('original size of features are ', 15820)
# training time: 0.079 s
# predict time: 0.0 s
# [1]
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
#!/usr/bin/python

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""



# Now, Full Training Set + RBF Kernel + C value 10000.0

# How Many Chris Emails Predicted? 




import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()

#########################################################
### your code goes here ###

print("original size of features are ", len(features_train))
from sklearn.svm import SVC

# C = 10000.0

clf = SVC(kernel="rbf", C=10000.0)

t0 = time()
# 1% training set
#features_train = features_train[:len(features_train)/100] 
#labels_train = labels_train[:len(labels_train)/100]
clf.fit(features_train, labels_train)
print "training time:", round(time()-t0, 3), "s"

t0 = time()
pred = clf.predict(features_test)
print "predict time:", round(time()-t0, 3), "s"

# Chris is [1]
answer = 0
for c in pred:
	if c == 1:
		answer +=1

print answer

#########################################################
# Out:
# no. of Chris training emails: 7936
# no. of Sara training emails: 7884
# ('original size of features are ', 15820)
# training time: 84.935 s
# predict time: 8.628 s
# 877
